# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://blog.jetbrains.com'

# %%
page = requests.get(url)
if page.status_code == 200:
    print('Success')
elif page.status_code == 404:
    print('Page not found')
elif page.status_code == 503:
    print('Service unavailable')
# Out:
# Success

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.title)
# Out:
# <title>JetBrains Blog: The Drive to Develop</title>

# %%
target = soup.find('div', class_ = 'latest')
print(target)
# Out:
# <div class="row latest card_container show_all last-col-home" data-all-post="11916" data-post-limit="12">
# <div class="col" post_id="386461">
# <a class="card" href="https://blog.jetbrains.com/fleet/2023/09/fleet-preview-update-1-23-updated-problems-view-rewrite-code-feature-download-file-to-action-for-remote-workspaces-and-more/">
# <div class="card__header">
# <time class="publish-date" data-day="12" data-month="09" data-year="2023" datetime="2023-09-12"></time>
# <h3>Fleet Preview Update 1.23: Updated <i>Problems</i> View, <i>Rewrite Code…</i> Feature, <i>Download File To…</i> Action for Remote Workspaces, and More</h3> </div>
# <div class="card__body">
# <p>Fleet 1.23 is now available!
#
#
#
# To the Fleet team, the sequence 1-2-3 symbolizes both the step-by-step growth of Fleet and the natural progression of your coding journey. Dive into this release, where (1) coding simplicity, (2) balance, and (3) creative enhancements come together to elevate your dev…</p>
# </div>
# <div class="card__footer">
# <div class="author">
# <img alt="Roman Prokashev" class="avatar avatar-200 wp-user-avatar wp-user-avatar-200 photo avatar-default" height="50" loading="lazy" src="https://blog.jetbrains.com/wp-content/uploads/2021/06/80718421_2591979197552910_3267075862792503296_n-50x50.jpeg" width="50"/>
# <span>Roman Prokashev</span>
# </div>
# <span class="remark42__counter icon-comments" data-url="https://blog.jetbrains.com/fleet/2023/09/fleet-preview-update-1-23-updated-problems-view-rewrite-code-feature-download-file-to-action-for-remote-workspaces-and-more/"></span>
# </div>
# </a>
# </div>
# <div class="col" post_id="386537">
# <a class="card img-visible" href="https://blog.jetbrains.com/kotlin/2023/09/algorithmic-challenges-in-kotlin-live/">
# <img alt="Algorithms in Kotin livestream" class="attachment-full size-full wp-post-image" decoding="async" fetchpriority="high" height="1200" sizes="(max-width: 768px) 768px , 525px" src="https://blog.jetbrains.com/wp-content/uploads/2023/09/Blog_Featured_image_1280x600-3.png" width="2560"> <div class="card__header">
# <time class="publish-date" data-day="12" data-month="09" data-year="2023" datetime="2023-09-12"></time>
# <h3>Join Us for a Live Introduction to Algorithmic Challenges in Kotlin!</h3> </div>
# <div class="card__body">
# <p>Are you preparing for technical interviews, or do you simply want to master algorithms? Join us for a practical livestream where we’ll introduce the Algorithmic Challenges in Kotlin course!</p>
# </div>
# <div class="card__footer">
# <div class="author">
# <img alt="Ksenia Shneyveys" class="avatar avatar-200 wp-user-avatar wp-user-avatar-200 photo avatar-default" height="50" loading="lazy" src="https://secure.gravatar.com/avatar/0bf682c12d2f26ff438eeefb2ca03bc0?s=50&amp;r=g" width="50"/>
# <span>Ksenia Shneyveys</span>
# </div>
# <span class="remark42__counter icon-comments" data-url="https://blog.jetbrains.com/kotlin/2023/09/algorithmic-challenges-in-kotlin-live/"></span>
# </div>
# </img></a>
# </div>
# <div class="col" post_id="384625">
# <a class="card img-visible" href="https://blog.jetbrains.com/teamcity/2023/09/how-gradle-uses-teamcity/">
# <img alt="How Gradle Uses TeamCity" class="attachment-full size-full wp-post-image" decoding="async" height="1440" sizes="(max-width: 768px) 768px , 525px" src="https://blog.jetbrains.com/wp-content/uploads/2023/09/how-Gradle-uses-TeamCity_page-preview-1-1-1.png" width="2560"> <div class="card__header">
# <time class="publish-date" data-day="12" data-month="09" data-year="2023" datetime="2023-09-12"></time>
# <h3>How Gradle Uses TeamCity to Run 30,000 Green Builds Per Day</h3> </div>
# <div class="card__body">
# <p>In this case study, we’ll take a deep look into how Gradle Build Tool uses TeamCity to run tens of thousands of builds a day, while keeping the failure rate under control.</p>
# </div>
# <div class="card__footer">
# <div class="author">
# <img alt="Olga Bedrina" class="avatar avatar-200 wp-user-avatar wp-user-avatar-200 photo avatar-default" height="50" loading="lazy" src="https://blog.jetbrains.com/wp-content/uploads/2023/01/olga-bedrina-headshot-1-50x50.jpeg" width="50"/>
# <span>Olga Bedrina</span>
# </div>
# <span class="remark42__counter icon-comments" data-url="https://blog.jetbrains.com/teamcity/2023/09/how-gradle-uses-teamcity/"></span>
# </div>
# </img></a>
# </div>
# <div class="col" post_id="385197">
# <a class="card img-visible" href="https://blog.jetbrains.com/idea/2023/09/jpa-buddy-and-react-buddy-join-jetbrains/">
# <img alt="" class="attachment-full size-full wp-post-image" decoding="async" height="1200" sizes="(max-width: 768px) 768px , 525px" src="https://blog.jetbrains.com/wp-content/uploads/2023/09/Space-Blog-1280x600-2x.png" width="2560"> <div class="card__header">
# <time class="publish-date" data-day="11" data-month="09" data-year="2023" datetime="2023-09-11"></time>
# <h3>JPA and React Plugins: From Buddies To Full Members of The JetBrains Family </h3> </div>
# <div class="card__body">
# <p>We are excited to announce that JPA Buddy and React Buddy have joined the JetBrains family. Positioned as powerful plugins for working with JPA data and React applications, respectively, they will offer even more functionality for IntelliJ IDEA and WebStorm developers moving forward.
#
#
#
# With this ac…</p>
# </div>
# <div class="card__footer">
# <div class="author">
# <img alt="Yuriy Artamonov" class="avatar avatar-200 wp-user-avatar wp-user-avatar-200 photo avatar-default" height="50" loading="lazy" src="https://secure.gravatar.com/avatar/feac7b655c02143652b49fbb0c85a2c3?s=50&amp;r=g" width="50"/>
# <span>Yuriy Artamonov</span>
# </div>
# <span class="remark42__counter icon-comments" data-url="https://blog.jetbrains.com/idea/2023/09/jpa-buddy-and-react-buddy-join-jetbrains/"></span>
# </div>
# </img></a>
# </div>
# <div class="col" post_id="385562">
# <a class="card webinar" href="https://blog.jetbrains.com/idea/2023/09/new-livestream-java-21-focus-on-virtual-threads-and-pattern-matching/">
# <img alt="" class="attachment-full size-full wp-post-image" decoding="async" height="1440" loading="lazy" sizes="(max-width: 768px) 768px , 525px" src="https://blog.jetbrains.com/wp-content/uploads/2023/09/Sep-2023-IntelliJ-IDEA-LiveStream-Jose-Paumard-Featured_Blog_image_1280x720-2x.png" width="2560"> <div class="card__body">
# <time datatime="28-09-2023"><i class="icon-date"></i>Sep 28 2023</time>
# <h3>New Livestream – Java 21: Focus on Virtual Threads and Pattern Matching</h3> <p>Join us for the new IntelliJ IDEA LiveStream episode with José Paumard to learn about the Java 21 release. Date: September 28, 2023. Time: 3:00 – 4:00 pm UTC.</p>
# </div>
# <div class="card__footer">
# <div class="author">
# <img alt="Anna Rovinskaia" class="avatar avatar-200 wp-user-avatar wp-user-avatar-200 photo avatar-default" height="50" loading="lazy" src="https://blog.jetbrains.com/wp-content/uploads/2023/07/E42E0143-839A-45D6-951B-109FCFC001B6-60590-0000178DD427D2AB-50x50.jpg" width="50"/>
# <span>Anna Rovinskaia</span>
# </div>
# </div>
# </img></a>
# </div>
# <div class="col" post_id="386308">
# <a class="card img-visible" href="https://blog.jetbrains.com/clion/2023/09/introducing-the-new-clion-conan-plugin/">
# <img alt="" class="attachment-full size-full wp-post-image" decoding="async" height="1440" sizes="(max-width: 768px) 768px , 525px" src="https://blog.jetbrains.com/wp-content/uploads/2023/09/CLion-blog-post-on-Conan_Featured_1280x720.png" width="2560"> <div class="card__header">
# <time class="publish-date" data-day="08" data-month="09" data-year="2023" datetime="2023-09-08"></time>
# <h3>Introducing the New CLion Conan Plugin</h3> </div>
# <div class="card__body">
# <p>We are thrilled to announce the launch of the new version of the Conan CLion Plugin, now compatible with the 2.X versions of Conan.</p>
# </div>
# <div class="card__footer">
# <div class="author">
# <img alt="Anastasia Kazakova" class="avatar avatar-200 wp-user-avatar wp-user-avatar-200 photo avatar-default" height="50" loading="lazy" src="https://blog.jetbrains.com/wp-content/uploads/2021/03/Anastasia-50x50.jpg" width="50"/>
# <span>Anastasia Kazakova</span>
# </div>
# <span class="remark42__counter icon-comments" data-url="https://blog.jetbrains.com/clion/2023/09/introducing-the-new-clion-conan-plugin/"></span>
# </div>
# </img></a>
# </div>
# <div class="col" post_id="385463">
# <a class="card img-visible" href="https://blog.jetbrains.com/qodana/2023/09/the-power-of-automation-enhancing-your-manual-code-review-process/">
# <img alt="Static code analysis" class="attachment-full size-full wp-post-image" decoding="async" height="1440" sizes="(max-width: 768px) 768px , 525px" src="https://blog.jetbrains.com/wp-content/uploads/2023/09/Featured_1280x720.png" width="2560"> <div class="card__header">
# <time class="publish-date" data-day="07" data-month="09" data-year="2023" datetime="2023-09-07"></time>
# <h3>The Power of Automation: Enhancing Your Manual Code Review Process</h3> </div>
# <div class="card__body">
# <p>Code reviews help you strategically dig deeper into your work. They enable you to identify bugs, potential fixes, vulnerabilities, and much more to ultimately improve the quality of your source code and your knowledge of it. This can have a direct impact on team learning, project build speed and qua…</p>
# </div>
# <div class="card__footer">
# <div class="author">
# <img alt="Kerry Beetge" class="avatar avatar-200 wp-user-avatar wp-user-avatar-200 photo avatar-default" height="50" loading="lazy" src="https://blog.jetbrains.com/wp-content/uploads/2023/07/kerry-beetge.256x256-50x50.jpg" width="50"/>
# <span>Kerry Beetge</span>
# </div>
# <span class="remark42__counter icon-comments" data-url="https://blog.jetbrains.com/qodana/2023/09/the-power-of-automation-enhancing-your-manual-code-review-process/"></span>
# </div>
# </img></a>
# </div>
# <div class="col" post_id="385738">
# <a class="card img-visible" href="https://blog.jetbrains.com/dotnet/2023/09/07/net-annotated-monthly-september-2023/">
# <img alt=".NET Annotated Monthly | September 2023" class="attachment-full size-full wp-post-image" decoding="async" height="1440" sizes="(max-width: 768px) 768px , 525px" src="https://blog.jetbrains.com/wp-content/uploads/2023/09/dotnet-annotated-featured_blog_1280x720.png" width="2560"> <div class="card__header">
# <time class="publish-date" data-day="07" data-month="09" data-year="2023" datetime="2023-09-07"></time>
# <h3>.NET Annotated Monthly | September 2023</h3> </div>
# <div class="card__body">
# <p>Did you know? The original usage of the term “computer” referred to people (mostly women), not machines. It’s possible that one day the word “programmer” could morph into meaning “AI”, and no longer refers to a person.
#
#
#
#
#
#
#
# .NET news
#
#
#
#
# Visual Studio for Mac Retirement Announcement 🚮…</p>
# </div>
# <div class="card__footer">
# <div class="author">
# <img alt="Rachel Appel" class="avatar avatar-200 wp-user-avatar wp-user-avatar-200 photo avatar-default" height="50" loading="lazy" src="https://secure.gravatar.com/avatar/e34736e840f97eeb2e6d2fe4db7aba22?s=50&amp;r=g" width="50"/>
# <span>Rachel Appel</span>
# </div>
# <span class="remark42__counter icon-comments" data-url="https://blog.jetbrains.com/dotnet/2023/09/07/net-annotated-monthly-september-2023/"></span>
# </div>
# </img></a>
# </div>
# <div class="col" post_id="385540">
# <a class="card img-visible" href="https://blog.jetbrains.com/education/2023/09/06/jetbrains-academy-s-new-projects-and-topics-september-update/">
# <img alt="" class="attachment-full size-full wp-post-image" decoding="async" height="1200" sizes="(max-width: 768px) 768px , 525px" src="https://blog.jetbrains.com/wp-content/uploads/2023/09/Blog_Featured_image_1280x600-2.png" width="2560"> <div class="card__header">
# <time class="publish-date" data-day="06" data-month="09" data-year="2023" datetime="2023-09-06"></time>
# <h3>JetBrains Academy’s New Projects and Topics: September Update</h3> </div>
# <div class="card__body">
# <p>The latest content update, featuring four new projects and more than 90 new topics to learn.</p>
# </div>
# <div class="card__footer">
# <div class="author">
# <img alt="Regina Muradova" class="avatar avatar-200 wp-user-avatar wp-user-avatar-200 photo avatar-default" height="50" loading="lazy" src="https://blog.jetbrains.com/wp-content/uploads/2022/12/69164930_3111702792189526_5633002784417644544_n-50x50.jpg" width="50"/>
# <span>Regina Muradova</span>
# </div>
# <span class="remark42__counter icon-comments" data-url="https://blog.jetbrains.com/education/2023/09/06/jetbrains-academy-s-new-projects-and-topics-september-update/"></span>
# </div>
# </img></a>
# </div>
# <div class="col" post_id="385255">
# <a class="card img-visible" href="https://blog.jetbrains.com/platform/2023/09/busy-plugin-developers-newsletter-summer-2023/">
# <img alt="" class="attachment-full size-full wp-post-image" decoding="async" height="1440" sizes="(max-width: 768px) 768px , 525px" src="https://blog.jetbrains.com/wp-content/uploads/2023/09/featured_blog-bpd-_1280x720.png" width="2560"> <div class="card__header">
# <time class="publish-date" data-day="05" data-month="09" data-year="2023" datetime="2023-09-05"></time>
# <h3>Busy Plugin Developers Newsletter – Summer 2023</h3> </div>
# <div class="card__body">
# <p>Read this blog post to discover what has come to JetBrains Marketplace this Summer!</p>
# </div>
# <div class="card__footer">
# <div class="author">
# <img alt="Elena Kerpeleva" class="avatar avatar-200 wp-user-avatar wp-user-avatar-200 photo avatar-default" height="50" loading="lazy" src="https://blog.jetbrains.com/wp-content/uploads/2023/09/IMG_20230616_122258-50x50.jpg" width="50"/>
# <span>Elena Kerpeleva</span>
# </div>
# <span class="remark42__counter icon-comments" data-url="https://blog.jetbrains.com/platform/2023/09/busy-plugin-developers-newsletter-summer-2023/"></span>
# </div>
# </img></a>
# </div>
# <div class="col" post_id="385018">
# <a class="card img-visible" href="https://blog.jetbrains.com/datalore/2023/09/05/what-s-new-in-datalore-enterprise-2023-4/">
# <img alt="Datalore Enterprise release 2023.4" class="attachment-full size-full wp-post-image" decoding="async" height="1440" sizes="(max-width: 768px) 768px , 525px" src="https://blog.jetbrains.com/wp-content/uploads/2023/09/Featured_image_1280x720_Datalore-2x.png" width="2560"> <div class="card__header">
# <time class="publish-date" data-day="05" data-month="09" data-year="2023" datetime="2023-09-05"></time>
# <h3>What’s New in Datalore Enterprise 2023.4</h3> </div>
# <div class="card__body">
# <p>Datalore Enterprise 2023.4 includes comments for notebooks and reports, a new Viewer license type, report sharing via email invitations, and other improvements</p>
# </div>
# <div class="card__footer">
# <div class="author">
# <img alt="Alina Anikina" class="avatar avatar-200 wp-user-avatar wp-user-avatar-200 photo avatar-default" height="50" loading="lazy" src="https://blog.jetbrains.com/wp-content/uploads/2023/07/Photo-61-50x50.jpg" width="50"/>
# <span>Alina Anikina</span>
# </div>
# <span class="remark42__counter icon-comments" data-url="https://blog.jetbrains.com/datalore/2023/09/05/what-s-new-in-datalore-enterprise-2023-4/"></span>
# </div>
# </img></a>
# </div>
# <div class="col" post_id="384951">
# <a class="card img-visible" href="https://blog.jetbrains.com/idea/2023/09/java-annotated-monthly-september-2023/">
# <img alt="" class="attachment-full size-full wp-post-image" decoding="async" height="1440" sizes="(max-width: 768px) 768px , 525px" src="https://blog.jetbrains.com/wp-content/uploads/2023/09/java-annotated-featured_blog_1280x720.png" width="2560"> <div class="card__header">
# <time class="publish-date" data-day="05" data-month="09" data-year="2023" datetime="2023-09-05"></time>
# <h3>Java Annotated Monthly – September 2023</h3> </div>
# <div class="card__body">
# <p>The September edition of Java Annotated Monthly is here!
#
#
#
# With this month’s release of Java 21 approaching, we're excited to bring you a final sneak peek into its crucial features. But that's not all! This edition is packed with helpful articles about cutting-edge AI technologies, including update…</p>
# </div>
# <div class="card__footer">
# <div class="author">
# <img alt="Irina Maryasova" class="avatar avatar-200 wp-user-avatar wp-user-avatar-200 photo avatar-default" height="50" loading="lazy" src="https://secure.gravatar.com/avatar/5deb5fdbb1c42239bffe4344b40a55ce?s=50&amp;r=g" width="50"/>
# <span>Irina Maryasova</span>
# </div>
# <span class="remark42__counter icon-comments" data-url="https://blog.jetbrains.com/idea/2023/09/java-annotated-monthly-september-2023/"></span>
# </div>
# </img></a>
# </div>
# </div>

# %%
target = soup.find('div', class_ = 'latest')
if target:
    print("target area found")
else:
    print("target area not found")
# Out:
# target area found

# %%
articles = target.find_all('div', class_='col')
if articles:
    print("articles found")
    total = len(articles)
    print("Total articles found :", total)
else:
    print("articles not found")
# Out:
# articles found
# Total articles found : 12

# %%
for item in articles:
    try: pubdate = item.find('time')['datetime']
    except: pubdate = None
    title = item.find('h3').text
    summary = item.find('p').text
    author = item.find('span').text

    print(title)
    print(summary)
    print(pubdate)
    print(author)
# Out:
# Fleet Preview Update 1.23: Updated Problems View, Rewrite Code… Feature, Download File To… Action for Remote Workspaces, and More
# Fleet 1.23 is now available!
#
#
#
# To the Fleet team, the sequence 1-2-3 symbolizes both the step-by-step growth of Fleet and the natural progression of your coding journey. Dive into this release, where (1) coding simplicity, (2) balance, and (3) creative enhancements come together to elevate your dev…
# 2023-09-12
# Roman Prokashev
# Join Us for a Live Introduction to Algorithmic Challenges in Kotlin!
# Are you preparing for technical interviews, or do you simply want to master algorithms? Join us for a practical livestream where we’ll introduce the Algorithmic Challenges in Kotlin course!
# 2023-09-12
# Ksenia Shneyveys
# How Gradle Uses TeamCity to Run 30,000 Green Builds Per Day
# In this case study, we’ll take a deep look into how Gradle Build Tool uses TeamCity to run tens of thousands of builds a day, while keeping the failure rate under control.
# 2023-09-12
# Olga Bedrina
# JPA and React Plugins: From Buddies To Full Members of The JetBrains Family
# We are excited to announce that JPA Buddy and React Buddy have joined the JetBrains family. Positioned as powerful plugins for working with JPA data and React applications, respectively, they will offer even more functionality for IntelliJ IDEA and WebStorm developers moving forward.
#
#
#
# With this ac…
# 2023-09-11
# Yuriy Artamonov
# New Livestream – Java 21: Focus on Virtual Threads and Pattern Matching
# Join us for the new IntelliJ IDEA LiveStream episode with José Paumard to learn about the Java 21 release. Date: September 28, 2023. Time: 3:00 – 4:00 pm UTC.
# None
# Anna Rovinskaia
# Introducing the New CLion Conan Plugin
# We are thrilled to announce the launch of the new version of the Conan CLion Plugin, now compatible with the 2.X versions of Conan.
# 2023-09-08
# Anastasia Kazakova
# The Power of Automation: Enhancing Your Manual Code Review Process
# Code reviews help you strategically dig deeper into your work. They enable you to identify bugs, potential fixes, vulnerabilities, and much more to ultimately improve the quality of your source code and your knowledge of it. This can have a direct impact on team learning, project build speed and qua…
# 2023-09-07
# Kerry Beetge
# .NET Annotated Monthly | September 2023
# Did you know? The original usage of the term “computer” referred to people (mostly women), not machines. It’s possible that one day the word “programmer” could morph into meaning “AI”, and no longer refers to a person.
#
#
#
#
#
#
#
# .NET news
#
#
#
#
# Visual Studio for Mac Retirement Announcement 🚮…
# 2023-09-07
# Rachel Appel
# JetBrains Academy’s New Projects and Topics: September Update
# The latest content update, featuring four new projects and more than 90 new topics to learn.
# 2023-09-06
# Regina Muradova
# Busy Plugin Developers Newsletter – Summer 2023
# Read this blog post to discover what has come to JetBrains Marketplace this Summer!
# 2023-09-05
# Elena Kerpeleva
# What’s New in Datalore Enterprise 2023.4
# Datalore Enterprise 2023.4 includes comments for notebooks and reports, a new Viewer license type, report sharing via email invitations, and other improvements
# 2023-09-05
# Alina Anikina
# Java Annotated Monthly – September 2023
# The September edition of Java Annotated Monthly is here!
#
#
#
# With this month’s release of Java 21 approaching, we're excited to bring you a final sneak peek into its crucial features. But that's not all! This edition is packed with helpful articles about cutting-edge AI technologies, including update…
# 2023-09-05
# Irina Maryasova
